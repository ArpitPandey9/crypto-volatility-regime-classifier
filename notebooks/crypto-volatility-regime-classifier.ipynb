# %% [markdown]
# # Crypto Volatility Regime Classifier
#
# This notebook is a lightweight entry point to the source modules. The public repository does not claim validated forward predictive performance.

# %%
from src.model import walk_forward_cv
walk_forward_cv(list(range(10)), list(range(10)), 6, 2)
